# %%
import matplotlib.pyplot as plt
from modules.var_commons import *

# %%
mdata = load_and_prepare_data('../../data/monthly-time-series/AI-izbori_stranke_krace_v2_INFL.csv', keep_columns=['NEODLUCNI', 'INFLACIJA'])

# %%
perform_adf_test(mdata)
# Out:
# Augmented Dickey-Fuller Test: HDZ
# ADF test statistic      -4.800344
# p-value                  0.000054
# # lags used              0.000000
# # observations          45.000000
# critical value (1%)     -3.584829
# critical value (5%)     -2.928299
# critical value (10%)    -2.602344
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: SDP
# ADF test statistic      -3.141262
# p-value                  0.023647
# # lags used              0.000000
# # observations          45.000000
# critical value (1%)     -3.584829
# critical value (5%)     -2.928299
# critical value (10%)    -2.602344
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: MOST
# ADF test statistic      -1.815637
# p-value                  0.372727
# # lags used              1.000000
# # observations          44.000000
# critical value (1%)     -3.588573
# critical value (5%)     -2.929886
# critical value (10%)    -2.603185
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: DP
# ADF test statistic      -2.315991
# p-value                  0.166862
# # lags used              1.000000
# # observations          44.000000
# critical value (1%)     -3.588573
# critical value (5%)     -2.929886
# critical value (10%)    -2.603185
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: MOZEMO
# ADF test statistic      -2.676627
# p-value                  0.078171
# # lags used              2.000000
# # observations          43.000000
# critical value (1%)     -3.592504
# critical value (5%)     -2.931550
# critical value (10%)    -2.604066
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: NEODLUCNI
# ADF test statistic      -3.153276
# p-value                  0.022854
# # lags used              0.000000
# # observations          45.000000
# critical value (1%)     -3.584829
# critical value (5%)     -2.928299
# critical value (10%)    -2.602344
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: INFLACIJA
# ADF test statistic      -1.717965
# p-value                  0.421881
# # lags used              1.000000
# # observations          44.000000
# critical value (1%)     -3.588573
# critical value (5%)     -2.929886
# critical value (10%)    -2.603185
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: HDZ (diff)
# ADF test statistic     -7.356699e+00
# p-value                 9.737963e-11
# # lags used             2.000000e+00
# # observations          4.200000e+01
# critical value (1%)    -3.596636e+00
# critical value (5%)    -2.933297e+00
# critical value (10%)   -2.604991e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: SDP (diff)
# ADF test statistic      -0.798248
# p-value                  0.819636
# # lags used              5.000000
# # observations          39.000000
# critical value (1%)     -3.610400
# critical value (5%)     -2.939109
# critical value (10%)    -2.608063
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: MOST (diff)
# ADF test statistic     -1.010848e+01
# p-value                 1.014985e-17
# # lags used             0.000000e+00
# # observations          4.400000e+01
# critical value (1%)    -3.588573e+00
# critical value (5%)    -2.929886e+00
# critical value (10%)   -2.603185e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: DP (diff)
# ADF test statistic     -9.420604e+00
# p-value                 5.516446e-16
# # lags used             0.000000e+00
# # observations          4.400000e+01
# critical value (1%)    -3.588573e+00
# critical value (5%)    -2.929886e+00
# critical value (10%)   -2.603185e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: MOZEMO (diff)
# ADF test statistic      -1.984386
# p-value                  0.293461
# # lags used             10.000000
# # observations          34.000000
# critical value (1%)     -3.639224
# critical value (5%)     -2.951230
# critical value (10%)    -2.614447
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: NEODLUCNI (diff)
# ADF test statistic      -4.867061
# p-value                  0.000040
# # lags used              5.000000
# # observations          39.000000
# critical value (1%)     -3.610400
# critical value (5%)     -2.939109
# critical value (10%)    -2.608063
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: INFLACIJA (diff)
# ADF test statistic      -2.557090
# p-value                  0.102194
# # lags used              0.000000
# # observations          44.000000
# critical value (1%)     -3.588573
# critical value (5%)     -2.929886
# critical value (10%)    -2.603185
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
mdata
# Out:
#              HDZ   SDP  MOST    DP  MOZEMO  NEODLUCNI  INFLACIJA
# 2024-04-01  25.4  22.5   6.9  10.8     2.7        9.2        1.0
# 2020-07-01  30.2  18.4   8.2   6.9     8.7        8.8        1.0
# 2020-08-01  33.1  16.4   7.0   6.1     8.6        9.9        1.0
# 2020-09-01  33.7  17.1   6.2   7.9     8.2       11.8        1.0
# 2020-10-01  32.5  18.7   7.3   8.4     6.7        9.9        1.0
# 2020-11-01  31.5  17.6   7.4   7.5     6.5       10.5        0.7
# 2020-12-01  30.8  16.2   8.3   9.4     8.6        5.1        0.1
# 2021-01-01  31.1  16.6   7.8   7.3     9.6        8.3       -0.3
# 2021-02-01  30.9  17.2   8.0   6.8     9.3       13.3        0.3
# 2021-03-01  29.1  16.0   7.3   6.2     9.4       16.6        1.2
# 2021-04-01  29.3  15.1   7.7   6.6     8.7       16.8        2.1
# 2021-05-01  30.5  15.2   6.7   7.3     9.4       13.7        2.1
# 2021-06-01  30.7  13.4   6.8   6.4    13.4       14.9        2.0
# 2021-07-01  29.8  14.3   7.6   7.7    14.9        8.0        2.8
# 2021-08-01  30.0  12.7   8.9   5.0    15.6       14.2        3.1
# 2021-09-01  30.8  13.4   8.3   5.2    13.6       15.1        3.3
# 2021-10-01  30.9  12.2   8.2   4.5    11.2       14.6        3.8
# 2021-11-01  29.5  13.3   9.4   4.8    10.3       17.6        4.8
# 2021-12-01  29.7  13.1  10.6   5.3     8.8       17.2        5.5
# 2022-01-01  30.4  13.5   8.8   6.0     9.4       16.8        5.7
# 2022-02-01  29.8  15.6  10.2   4.6     9.8       16.9        6.3
# 2022-03-01  28.1  14.0  10.7   5.6    10.1       16.0        7.3
# 2022-04-01  28.6  15.9   9.0   4.8     9.1       16.4        9.4
# 2022-05-01  30.0  14.1  10.2   5.6    10.2       12.6       10.8
# 2022-06-01  29.3  12.8   9.1   6.3     8.9       16.8       12.1
# 2022-07-01  29.1  13.9   8.2   5.1     9.9       16.8       12.3
# 2022-08-01  30.1  13.2   9.2   4.0     9.0       16.4       12.3
# 2022-09-01  28.1  13.2   8.6   5.7     8.4       13.2       12.8
# 2022-10-01  28.4  12.7   8.9   6.2     7.9       12.3       13.2
# 2022-11-01  29.9  11.7   8.3   5.8     8.6       17.5       13.5
# 2022-12-01  30.7  12.3   8.0   6.8     7.5       17.7       13.1
# 2023-01-01  30.0  11.6   8.7   6.3     8.0       16.5       12.7
# 2023-02-01  29.3  12.2   9.0   5.7     8.6       15.1       12.0
# 2023-03-01  30.4  12.4   8.4   6.4     7.2       19.2       10.7
# 2023-04-01  30.9  13.6   8.7   6.0     8.8       17.0        8.9
# 2023-05-01  30.3  12.6   7.3   6.9     9.0       17.3        7.9
# 2023-06-01  28.6  11.7   8.9   7.2    10.0       18.3        7.6
# 2023-07-01  29.4  10.7   8.0   7.1    10.6       15.4        7.3
# 2023-08-01  27.9  11.5   8.7   6.5    10.4       16.9        7.8
# 2023-09-01  29.9  12.4   8.9   6.5     9.0       16.9        6.7
# 2023-10-01  29.8  13.4   9.2   7.7     8.2       16.6        5.8
# 2023-11-01  29.5  12.6   8.1   7.9     7.9       18.0        4.7
# 2023-12-01  28.2  12.9   7.5   8.4     6.8       19.7        4.5
# 2024-01-01  29.1  13.5   6.7   7.6     6.6       18.6        4.1
# 2024-02-01  28.7  13.9   7.0   6.9     7.6       18.1        3.8
# 2024-03-01  30.4  20.5   6.7   8.5     8.0       13.6        4.9

# %%
# find_optimal_model_params(mdata, max_order=4)

# %%
mse = perform_var_using_test_set(mdata=mdata, max_lags=4, test_set_size=4)
print(f'Total MSE: {mse}')
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 4, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 4 based on aic criterion
# Discarding 0 observations
# MSE: 7.932867073459626
# Actual values: [[30.4 20.5  6.7  8.5  8. ]]
# Predicted values: [[28.98096962 14.43363051  7.12391438  9.31823535  7.97476408]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 4, BIC -> 0, FPE -> 4, HQIC ->  4>
# Using 4 based on aic criterion
# Discarding 1 observations
# MSE: 1.6224055868437297
# Actual values: [[28.7 13.9  7.   6.9  7.6]]
# Predicted values: [[29.85258947 13.13298402  6.98525247  9.38843075  7.54758956]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 4, BIC -> 0, FPE -> 4, HQIC ->  4>
# Using 4 based on aic criterion
# Discarding 2 observations
# MSE: 1.6372328593113359
# Actual values: [[29.1 13.5  6.7  7.6  6.6]]
# Predicted values: [[26.76020456 12.97307952  7.84849444  8.61632879  6.31379606]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 4, BIC -> 0, FPE -> 4, HQIC ->  4>
# Using 4 based on aic criterion
# Discarding 3 observations
# MSE: 3.3342853238142043
# Actual values: [[28.2 12.9  7.5  8.4  6.8]]
# Predicted values: [[27.3537532   9.94432188  7.67843074  8.74198759  9.45903494]]
#
# Total MSE: 3.6316977108572237
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
mse = perform_var_using_test_set(mdata=mdata, max_lags=3, test_set_size=4)
print(f'Total MSE: {mse}')
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 0 observations
# MSE: 11.35548379691702
# Actual values: [[30.4 20.5  6.7  8.5  8. ]]
# Predicted values: [[28.25217009 13.78170188  7.50640945  6.06362414  8.66520105]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 3, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 3 based on aic criterion
# Discarding 1 observations
# MSE: 1.146448410332955
# Actual values: [[28.7 13.9  7.   6.9  7.6]]
# Predicted values: [[29.34644872 12.75968765  6.58712948  8.50666156  6.47651862]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 3, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 3 based on aic criterion
# Discarding 2 observations
# MSE: 2.045745311208619
# Actual values: [[29.1 13.5  6.7  7.6  6.6]]
# Predicted values: [[26.90429007 11.56626236  7.38332783  8.69505596  6.553538  ]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 3, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 3 based on aic criterion
# Discarding 3 observations
# MSE: 0.8156427600865973
# Actual values: [[28.2 12.9  7.5  8.4  6.8]]
# Predicted values: [[28.11309093 11.61625501  8.28268749  8.94514699  8.02998962]]
#
# Total MSE: 3.840830069636298
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
mse = perform_var_using_test_set(mdata=mdata, max_lags=2, test_set_size=4)
print(f'Total MSE: {mse}')
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 0 observations
# MSE: 11.35548379691702
# Actual values: [[30.4 20.5  6.7  8.5  8. ]]
# Predicted values: [[28.25217009 13.78170188  7.50640945  6.06362414  8.66520105]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 1 observations
# MSE: 0.5184106422237569
# Actual values: [[28.7 13.9  7.   6.9  7.6]]
# Predicted values: [[29.72639649 13.6065418   6.46576144  7.00218696  6.52454999]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 2 observations
# MSE: 2.2314990213135557
# Actual values: [[29.1 13.5  6.7  7.6  6.6]]
# Predicted values: [[26.3049798  13.5778895   7.28082508  9.02650625  5.61663203]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 3 observations
# MSE: 0.3702162054204918
# Actual values: [[28.2 12.9  7.5  8.4  6.8]]
# Predicted values: [[28.5541093  12.60105509  7.42492733  8.32954139  8.07503696]]
#
# Total MSE: 3.6189024164687065
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
mse = perform_var_using_test_set(mdata=mdata, max_lags=1, test_set_size=4)
print(f'Total MSE: {mse}')
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 0 observations
# MSE: 11.35548379691702
# Actual values: [[30.4 20.5  6.7  8.5  8. ]]
# Predicted values: [[28.25217009 13.78170188  7.50640945  6.06362414  8.66520105]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 1 observations
# MSE: 0.5184106422237569
# Actual values: [[28.7 13.9  7.   6.9  7.6]]
# Predicted values: [[29.72639649 13.6065418   6.46576144  7.00218696  6.52454999]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 2 observations
# MSE: 2.2314990213135557
# Actual values: [[29.1 13.5  6.7  7.6  6.6]]
# Predicted values: [[26.3049798  13.5778895   7.28082508  9.02650625  5.61663203]]
#
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# Discarding 3 observations
# MSE: 0.3702162054204918
# Actual values: [[28.2 12.9  7.5  8.4  6.8]]
# Predicted values: [[28.5541093  12.60105509  7.42492733  8.32954139  8.07503696]]
#
# Total MSE: 3.6189024164687065
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
mdata = load_and_prepare_data('../../data/monthly-time-series/AI-izbori_stranke_krace_v2_INFL.csv', keep_columns=['NEODLUCNI', 'INFLACIJA'])

mse, df_forecast, actual, predicted = perform_var_analysis(mdata, max_lags=1, test_size=1)
print(f'MSE: {mse}')
print(f'Actual: {actual}')
print(f'Predicted: {predicted}')
# Out:
# <statsmodels.tsa.vector_ar.var_model.LagOrderResults object. Selected orders are: AIC -> 1, BIC -> 0, FPE -> 1, HQIC ->  0>
# Using 1 based on aic criterion
# MSE: 11.35548379691702
# Actual:              HDZ   SDP  MOST   DP  MOZEMO
# 2024-03-01  30.4  20.5   6.7  8.5     8.0
# Predicted:             HDZforecast  SDPforecast  MOSTforecast  DPforecast  MOZEMOforecast
# 2024-03-01     28.25217    13.781702      7.506409    6.063624        8.665201
# C:\Users\dsmoljan\Desktop\AI izbori\parlametrika\venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
parties = ["HDZ", "SDP", "MOST", "DP", "MOZEMO"]

plt.figure(figsize=(12, 6))

# Plot the actual values for each column in parties
plt.plot(mdata.index, mdata['HDZ'], label=f'HDZ', color='blue')
plt.plot(mdata.index, mdata['SDP'], label=f'SDP', color='red')
plt.plot(mdata.index, mdata['MOST'], label=f'MOST', color='darkorange')
plt.plot(mdata.index, mdata['DP'], label=f'DP', color='black')
plt.plot(mdata.index, mdata['MOZEMO'], label=f'MOZEMO', color='green')


# Plot the predicted values for each column in parties as a single dot for each party
plt.scatter(df_forecast.index, df_forecast['HDZforecast'], color='blue', s=20)
plt.scatter(df_forecast.index, df_forecast['SDPforecast'], color='red', s=20)
plt.scatter(df_forecast.index, df_forecast['MOSTforecast'], color='darkorange', s=20)
plt.scatter(df_forecast.index, df_forecast['DPforecast'], color='black', s=20)
plt.scatter(df_forecast.index, df_forecast['MOZEMOforecast'], color='green', s=20)

# Set the x-axis label
plt.xlabel('Date')

# Set the y-axis label
plt.ylabel('Percentage')

# Add a legend below the plot, all in one row, with thick lines
plt.legend(loc='upper center', ncol=5, fancybox=True, shadow=True, bbox_to_anchor=(0.5, -0.1), fontsize='small')

# add y labels on both sides
plt.tick_params(axis='y', which='both', labelleft=True, labelright=True)

# add y ticks on the right side
plt.tick_params(axis='y', which='both', right=True)

# Show the plot
plt.show()
